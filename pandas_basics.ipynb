# %%
pip install pandas

# %%
import pandas as pd
data = {'Name': ['Alice', 'Bob', 'Charlie'],
        'Age': [25, 30, 35],
        'City': ['New York', 'Los Angeles', 'Chicago']}
df = pd.DataFrame(data)
print(df)
# Out:
#       Name  Age         City
# 0    Alice   25     New York
# 1      Bob   30  Los Angeles
# 2  Charlie   35      Chicago

# %%
df.columns
# Out:
# Index(['Name', 'Age', 'City'], dtype='object')

# %%
 df1 = pd.read_csv("IMDB-Movie-Data.csv")

# %%
df1.head()
# Out:
#    Rank                    Title                     Genre  \
# 0     1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1     2               Prometheus  Adventure,Mystery,Sci-Fi
# 2     3                    Split           Horror,Thriller
# 3     4                     Sing   Animation,Comedy,Family
# 4     5            Suicide Squad  Action,Adventure,Fantasy
#
#                                          Description              Director  \
# 0  A group of intergalactic criminals are forced ...            James Gunn
# 1  Following clues to the origin of mankind, a te...          Ridley Scott
# 2  Three girls are kidnapped by a man with a diag...    M. Night Shyamalan
# 3  In a city of humanoid animals, a hustling thea...  Christophe Lourdelet
# 4  A secret government agency recruits some of th...            David Ayer
#
#                                               Actors  Year  Runtime (Minutes)  \
# ...

# %%
df1.tail()
# Out:
#      Rank                   Title                  Genre  \
# 995   996    Secret in Their Eyes    Crime,Drama,Mystery
# 996   997         Hostel: Part II                 Horror
# 997   998  Step Up 2: The Streets    Drama,Music,Romance
# 998   999            Search Party       Adventure,Comedy
# 999  1000              Nine Lives  Comedy,Family,Fantasy
#
#                                            Description          Director  \
# 995  A tight-knit team of rising investigators, alo...         Billy Ray
# 996  Three American college students studying abroa...          Eli Roth
# 997  Romantic sparks occur between two dance studen...        Jon M. Chu
# 998  A pair of friends embark on a mission to reuni...    Scot Armstrong
# 999  A stuffy businessman finds himself trapped ins...  Barry Sonnenfeld
#
#                                                 Actors  Year  \
# 995  Chiwetel Ejiofor, Nicole Kidman, Julia Roberts...  2015
# ...

# %%
df1.head(300)
# Out:
#      Rank                      Title                       Genre  \
# 0       1    Guardians of the Galaxy     Action,Adventure,Sci-Fi
# 1       2                 Prometheus    Adventure,Mystery,Sci-Fi
# 2       3                      Split             Horror,Thriller
# 3       4                       Sing     Animation,Comedy,Family
# 4       5              Suicide Squad    Action,Adventure,Fantasy
# ..    ...                        ...                         ...
# 295   296                 The Choice               Drama,Romance
# 296   297  Ice Age: Collision Course  Animation,Adventure,Comedy
# 297   298      The Devil Wears Prada                Comedy,Drama
# 298   299            The Infiltrator       Biography,Crime,Drama
# 299   300        There Will Be Blood               Drama,History
#
#                                            Description              Director  \
# 0    A group of intergalactic criminals are forced ...            James Gunn
# ...

# %%
df1.describe()
# Out:
#               Rank         Year  Runtime (Minutes)       Rating         Votes  \
# count  1000.000000  1000.000000        1000.000000  1000.000000  1.000000e+03
# mean    500.500000  2012.783000         113.172000     6.723200  1.698083e+05
# std     288.819436     3.205962          18.810908     0.945429  1.887626e+05
# min       1.000000  2006.000000          66.000000     1.900000  6.100000e+01
# 25%     250.750000  2010.000000         100.000000     6.200000  3.630900e+04
# 50%     500.500000  2014.000000         111.000000     6.800000  1.107990e+05
# 75%     750.250000  2016.000000         123.000000     7.400000  2.399098e+05
# max    1000.000000  2016.000000         191.000000     9.000000  1.791916e+06
#
#        Revenue (Millions)   Metascore
# count          872.000000  936.000000
# mean            82.956376   58.985043
# std            103.253540   17.194757
# min              0.000000   11.000000
# 25%             13.270000   47.000000
# ...

# %%
df1.dtypes
# Out:
# Rank                    int64
# Title                  object
# Genre                  object
# Description            object
# Director               object
# Actors                 object
# Year                    int64
# Runtime (Minutes)       int64
# Rating                float64
# Votes                   int64
# Revenue (Millions)    float64
# Metascore             float64
# dtype: object

# %%
df1.isnull().sum()
# Out:
# Rank                    0
# Title                   0
# Genre                   0
# Description             0
# Director                0
# Actors                  0
# Year                    0
# Runtime (Minutes)       0
# Rating                  0
# Votes                   0
# Revenue (Millions)    128
# Metascore              64
# dtype: int64

# %%
df1['Actors']
# Out:
# 0      Chris Pratt, Vin Diesel, Bradley Cooper, Zoe S...
# 1      Noomi Rapace, Logan Marshall-Green, Michael Fa...
# 2      James McAvoy, Anya Taylor-Joy, Haley Lu Richar...
# 3      Matthew McConaughey,Reese Witherspoon, Seth Ma...
# 4      Will Smith, Jared Leto, Margot Robbie, Viola D...
#                              ...
# 995    Chiwetel Ejiofor, Nicole Kidman, Julia Roberts...
# 996    Lauren German, Heather Matarazzo, Bijou Philli...
# 997    Robert Hoffman, Briana Evigan, Cassie Ventura,...
# 998    Adam Pally, T.J. Miller, Thomas Middleditch,Sh...
# 999    Kevin Spacey, Jennifer Garner, Robbie Amell,Ch...
# Name: Actors, Length: 1000, dtype: object

# %%
df1[['Title','Genre']]
# Out:
#                        Title                     Genre
# 0    Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1                 Prometheus  Adventure,Mystery,Sci-Fi
# 2                      Split           Horror,Thriller
# 3                       Sing   Animation,Comedy,Family
# 4              Suicide Squad  Action,Adventure,Fantasy
# ..                       ...                       ...
# 995     Secret in Their Eyes       Crime,Drama,Mystery
# 996          Hostel: Part II                    Horror
# 997   Step Up 2: The Streets       Drama,Music,Romance
# 998             Search Party          Adventure,Comedy
# 999               Nine Lives     Comedy,Family,Fantasy
#
# [1000 rows x 2 columns]

# %%
 cols = df1[['Rank','Description','Director']]

# %%
cols
# Out:
#      Rank                                        Description  \
# 0       1  A group of intergalactic criminals are forced ...
# 1       2  Following clues to the origin of mankind, a te...
# 2       3  Three girls are kidnapped by a man with a diag...
# 3       4  In a city of humanoid animals, a hustling thea...
# 4       5  A secret government agency recruits some of th...
# ..    ...                                                ...
# 995   996  A tight-knit team of rising investigators, alo...
# 996   997  Three American college students studying abroa...
# 997   998  Romantic sparks occur between two dance studen...
# 998   999  A pair of friends embark on a mission to reuni...
# 999  1000  A stuffy businessman finds himself trapped ins...
#
#                  Director
# 0              James Gunn
# 1            Ridley Scott
# 2      M. Night Shyamalan
# 3    Christophe Lourdelet
# 4              David Ayer
# ..                    ...
# 995             Billy Ray
# ...

# %%
type(cols)
# Out:
# pandas.core.frame.DataFrame

# %%
df1['Title'][1:300:10]
# Out:
# 1                              Prometheus
# 11                         Hidden Figures
# 21                  Manchester by the Sea
# 31                      Nocturnal Animals
# 41                              Moonlight
# 51                 Underworld: Blood Wars
# 61                The Autopsy of Jane Doe
# 71                                 Allied
# 81                      Captain Fantastic
# 91                               Warcraft
# 101                                  Thor
# 111                      12 Years a Slave
# 121                             Divergent
# 131                        Into the Woods
# 141                  Diary of a Wimpy Kid
# 151                      The Hunger Games
# 161                             Free Fire
# 171              Kubo and the Two Strings
# 181    The VVitch: A New-England Folktale
# 191                       Below Her Mouth
# 201                   A Cure for Wellness
# 211                       Spring Breakers
# ...

# %%
df1.columns
# Out:
# Index(['Rank', 'Title', 'Genre', 'Description', 'Director', 'Actors', 'Year',
#        'Runtime (Minutes)', 'Rating', 'Votes', 'Revenue (Millions)',
#        'Metascore'],
#       dtype='object')

# %%
df1.iloc[1:5]
# Out:
#    Rank          Title                     Genre  \
# 1     2     Prometheus  Adventure,Mystery,Sci-Fi
# 2     3          Split           Horror,Thriller
# 3     4           Sing   Animation,Comedy,Family
# 4     5  Suicide Squad  Action,Adventure,Fantasy
#
#                                          Description              Director  \
# 1  Following clues to the origin of mankind, a te...          Ridley Scott
# 2  Three girls are kidnapped by a man with a diag...    M. Night Shyamalan
# 3  In a city of humanoid animals, a hustling thea...  Christophe Lourdelet
# 4  A secret government agency recruits some of th...            David Ayer
#
#                                               Actors  Year  Runtime (Minutes)  \
# 1  Noomi Rapace, Logan Marshall-Green, Michael Fa...  2012                124
# 2  James McAvoy, Anya Taylor-Joy, Haley Lu Richar...  2016                117
# 3  Matthew McConaughey,Reese Witherspoon, Seth Ma...  2016                108
# ...

# %%
df1.iloc[0:5]
# Out:
#    Rank                    Title                     Genre  \
# 0     1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1     2               Prometheus  Adventure,Mystery,Sci-Fi
# 2     3                    Split           Horror,Thriller
# 3     4                     Sing   Animation,Comedy,Family
# 4     5            Suicide Squad  Action,Adventure,Fantasy
#
#                                          Description              Director  \
# 0  A group of intergalactic criminals are forced ...            James Gunn
# 1  Following clues to the origin of mankind, a te...          Ridley Scott
# 2  Three girls are kidnapped by a man with a diag...    M. Night Shyamalan
# 3  In a city of humanoid animals, a hustling thea...  Christophe Lourdelet
# 4  A secret government agency recruits some of th...            David Ayer
#
#                                               Actors  Year  Runtime (Minutes)  \
# ...

# %%
df1['Runtime (Minutes)']>120
# Out:
# 0       True
# 1       True
# 2      False
# 3      False
# 4       True
#        ...
# 995    False
# 996    False
# 997    False
# 998    False
# 999    False
# Name: Runtime (Minutes), Length: 1000, dtype: bool

# %%
df1[df1['Runtime (Minutes)']>120]
# Out:
#      Rank                    Title                       Genre  \
# 0       1  Guardians of the Galaxy     Action,Adventure,Sci-Fi
# 1       2               Prometheus    Adventure,Mystery,Sci-Fi
# 4       5            Suicide Squad    Action,Adventure,Fantasy
# 6       7               La La Land          Comedy,Drama,Music
# 8       9       The Lost City of Z  Action,Adventure,Biography
# ..    ...                      ...                         ...
# 972   973             Rock of Ages        Comedy,Drama,Musical
# 974   975           Queen of Katwe       Biography,Drama,Sport
# 982   983      Across the Universe       Drama,Fantasy,Musical
# 989   990                    Selma     Biography,Drama,History
# 991   992         Taare Zameen Par          Drama,Family,Music
#
#                                            Description         Director  \
# 0    A group of intergalactic criminals are forced ...       James Gunn
# ...

# %%
df1 = df1['Runtime_increment_by_10'] = df1['Runtime (Minutes)']+10;
